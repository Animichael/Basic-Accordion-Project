# %% [markdown]
# <a href="https://colab.research.google.com/github/Animichael/Basic-Accordion-Project/blob/main/Breast_Cancer_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DEVELOPING A BREAST CANCER MODEL USING LOGISTIC RESGRESSION

# %%
# IMPORTING THE NECESSARY PYTHON LIRARIES
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  LogisticRegression
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
# LOADING THE DATASET
cancer_data_set =pd.read_csv('/content/cancer_dataset.csv')

# %%
# PRINTING THE FIRST FIVE ROWS OF THE DATASET
cancer_data_set.head(5)
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
# PRINTING THE LAST FIVE ROOWS OF THE DATASET
cancer_data_set.tail(5)
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424        21.56         22.39          142.00     1479.0
# 565  926682        20.13         28.25          131.20     1261.0
# 566  926954        16.60         28.08          108.30      858.1
# 567  927241        20.60         29.33          140.10     1265.0
# 568   92751         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
# CHECK FOR THE SIZE OF THE DATASET
cancer_data_set.shape
# Out:
# (569, 32)

# %%
# TAIKING STATISTICAL ANALYSIS ABOUT THE DATASET
cancer_data_set.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
# CHECKING FOR INFRMATION ABOUT THE DATASET
cancer_data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
# CHECKING FOR MISSING DATA IN THE DATASET
cancer_data_set.isnull().sum()
# Out:
# id                         0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# label                      0
# ...

# %%
# THERE ARE NO MISSING VALUES. okay, LETS CHECK FOR THE SUM OF ALL THE MISSING VALUES
cancer_data_set.isnull().sum().sum()
# Out:
# 0

# %%
# CHECKING THE DISTRIBUTION OF THE TARGET VARIABLE 'Label'  ==> 1 represent malignant and 0 represent Benign
cancer_data_set['label'].value_counts()
# Out:
# 0    285
# 1    284
# Name: label, dtype: int64

# %%
# CHECKING THE MEAN OF THE TARGET VARIABLE
cancer_data_set.groupby('label').mean()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean   area_mean  \
# label
# 0      3.029162e+07    14.180639     19.215439       92.345719  660.755088
# 1      3.045233e+07    14.073757     19.364120       91.591021  649.002465
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# label
# 0             0.097036          0.105310        0.091038             0.049613
# 1             0.095682          0.103369        0.086553             0.048223
#
#        symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# label                 ...
# 0           0.180919  ...     16.368796      25.530000       107.840737
# 1           0.181406  ...     16.169232      25.824965       106.679648
#
#        area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# label
# 0      892.445965          0.133523           0.255188         0.277355
# 1      868.678521          0.131210           0.253338         0.267004
#
# ...

# %%
# SEPARATING THE FEASTURES AND TARGET
x = cancer_data_set.drop(columns='label', axis=1)
y =cancer_data_set['label']

# %%
# PRINTING THE VALUE OF X ----------VARIABLE
print(x)
# Out:
#            id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302        17.99         10.38          122.80     1001.0
# 1      842517        20.57         17.77          132.90     1326.0
# 2    84300903        19.69         21.25          130.00     1203.0
# 3    84348301        11.42         20.38           77.58      386.1
# 4    84358402        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564    926424        21.56         22.39          142.00     1479.0
# 565    926682        20.13         28.25          131.20     1261.0
# 566    926954        16.60         28.08          108.30      858.1
# 567    927241        20.60         29.33          140.10     1265.0
# 568     92751         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
# PRINTING THE VALUE OF THE y --------------------> VARIABLE
print(y)
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 564    1
# 565    0
# 566    0
# 567    0
# 568    0
# Name: label, Length: 569, dtype: int64

# %%
# SPLITING THE DATA INTO TRAINING AND TESTING DATA
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
# CHECKING HOW MANY DATA POINTS ARE THERE IN THE x  train and test

print(x.shape,x_train.shape, x_test.shape )
# Out:
# (569, 31) (455, 31) (114, 31)

# %%
 #CHECKING HOW MANY DATA POINTS ARE THERE IN THE y  train and test

print(y.shape,y_train.shape, y_test.shape )
# Out:
# (569,) (455,) (114,)

# %% [markdown]
# MODEL TRAINING

# %%
# USING LOGISTIC REGRESSION
model=LogisticRegression()

# %%
# TRAINING THE LOGISTIC REGRESSION MODEL USING THE TRAINING DATA
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# MODEL EVALUATION

# %%
# Accuracy score

# ACCURACY ON THE TRAINING DATA
x_train_prediction = model.predict(x_train)
training_data_accuracy = accuracy_score(y_train, x_train_prediction)
print(" THE ACCURACY SCORE FOR THE TRAIN DATA IS: ",training_data_accuracy )
# Out:
#  THE ACCURACY SCORE FOR THE TRAIN DATA IS:  0.5032967032967033

# %%
# ACCURACY ON THE TEST DATA
x_test_prediction = model.predict(x_test)
test_data_accuracy = accuracy_score(y_test, x_test_prediction)
print(" THE ACCURACY SCORE FOR THE Test DATA IS: ",test_data_accuracy )
# Out:
#  THE ACCURACY SCORE FOR THE Test DATA IS:  0.49122807017543857

# %% [markdown]
# BUILDING THE PREDICTING SYSTEM

# %%
input_data = (
84458202,13.71,20.83,90.2,577.9,0.1189,0.1645,0.09366,0.05985,0.2196,0.07451,0.5835,1.377,3.856,50.96,0.008805,0.03029,0.02488,0.01448,0.01486,0.005412,17.06,28.14,110.6,897,0.1654,0.3682,0.2678,0.1556,0.3196,0.1151)
# changing the input data to numpy array
input_data_as_numpy_array=np.asarray(input_data)

# reshaping the numpy array as we are predicting for one datapoint
input_data_reshaped = input_data_as_numpy_array.reshape(1, -2)

prediction =model.predict(input_data_reshaped)
 # printing the prediction
print(prediction)

if(prediction[0]==0):
  print('The  cancer type is benigh , the patient do not have breast cancer')

else:
    print('The  cancer type is Malignant , the patient has breast cancer')
# Out:
# [0]
# The  cancer type is benigh , the patient do not have breast cancer
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
